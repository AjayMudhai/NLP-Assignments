# %%
from urllib import request
import nltk
nltk.download('averaged_perceptron_tagger')
nltk.download('punkt')
url = "http://www.gutenberg.org/files/74/74-0.txt"
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np
import operator
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/ajaymudhai/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/ajaymudhai/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
response = request.urlopen(url)
raw = response.read().decode('utf8')
type(raw)
# Out:
# str

# %%
len(raw)
# Out:
# 421926

# %%
tokens=nltk.word_tokenize(raw)
len(tokens)
# Out:
# 91299

# %%
types=set(tokens)
print(len(types))
# Out:
# 9278

# %%
TTR=len(types)/len(tokens)
print(TTR)
# Out:
# 0.10162214263025882

# %% [markdown]
# # Tokens=91299
# # Types=9278
# # TTR = 0.1016

# %%
d={}
for x in tokens:
    d.setdefault(x,0)
    d[x]+=1
sorted_d = sorted(d.items(), key=operator.itemgetter(1),reverse=True)

# %% [markdown]
# # Test for Zipf's law:

# %%
y=[]
x=[]
for z in sorted_d:
    x.append(len(z[0]))
    y.append(z[1])

# %%
fig = plt.figure()
ax = plt.axes()


ax.plot(x,y)
plt.title("Word Length vs Frequency plot")
plt.xlabel("Word Length")
plt.ylabel("Frequency");

# %% [markdown]
# ## Zipf's Law for length seems to hold true from above plot. We can clearly see as the length of words increases, Frequency of their appearance in Corpus gets decreased.

# %% [markdown]
# ## Zipf's law for meanings seems to hold true most of the time for content words but not that much applicable over function words

# %% [markdown]
# # Heap's Law

# %%
tokenCount = nltk.FreqDist(tokens)

# %%
tokenCount.plot(100, cumulative=True)
